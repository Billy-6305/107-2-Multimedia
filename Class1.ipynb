# %% [markdown]
# <a href="https://colab.research.google.com/github/Billypeng1231/107-2-Multimedia/blob/master/Class1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
cv2.__version__
# Out:
# '3.4.3'

# %%
import sys

from google.colab import drive
drive.mount('/content/drive')

# !ls /content/drive/My\ Drive/test
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 1.jpg			 stock-photo-133673159.jpg
# pexels-photo-556416.jpg  stock-photo-137103573.jpg

# %%
from matplotlib import pyplot as plt


if __name__ =="__main__":
  if len(sys.argv)>1:
    image = cv2.imread('/content/drive/My Drive/test/1.jpg', cv2.IMREAD_ANYCOLOR)
    image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
  else:
    print("Usge:python firstOpenCV3.py imageFile")
  #cv2.imshow("image",image)
  #cv2.waitKey(0)
  #cv2.destroyAllWindows()
  plt.imshow(image)
  plt.show()

# %%
image.shape
# Out:
# (720, 720, 3)
