# %% [markdown]
# <a href="https://colab.research.google.com/github/Billypeng1231/107-2-Multimedia/blob/master/class3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
import cv2
import numpy as np
from matplotlib import pyplot as plt
from google.colab import drive
drive.mount('/content/drive')

#主函數
if __name__ =="__main__":
  if len(sys.argv)>1:
    image = cv2.imread('/content/drive/My Drive/test/1.jpg', cv2.IMREAD_GRAYSCALE)
  else:
    print("Usge:python imgToArray.py imageFile")
  plt.imshow(image,cmap='gray')
  plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
image2 = cv2.imread('/content/drive/My Drive/test/1.jpg', cv2.IMREAD_COLOR)
# plt.imshow(image2)
plt.imshow(cv2.cvtColor(image2,cv2.COLOR_BGR2RGB))
plt.show()

# %%
image4 = cv2.imread('/content/drive/My Drive/test/1.jpg', 0)
plt.imshow(image4)
plt.title('invert')
plt.xticks([])
plt.yticks([])
plt.show()

# %%
image5 = cv2.imread('/content/drive/My Drive/test/1.jpg')
gray = cv2.cvtColor(image5, cv2.COLOR_BGR2GRAY)
gray
# Out:
# array([[221, 220, 219, ..., 184, 183, 182],
#        [221, 221, 220, ..., 184, 183, 182],
#        [222, 222, 221, ..., 185, 184, 183],
#        ...,
#        [ 85,  74, 139, ..., 101,  99, 128],
#        [112,  76, 124, ...,  96,  88, 114],
#        [ 96,  74,  81, ..., 108,  98, 122]], dtype=uint8)

# %%
plt.imshow(gray,cmap='gray')
plt.title('gray')
plt.xticks([])
plt.yticks([])
plt.show()

# %%
image6 = cv2.imread('/content/drive/My Drive/test/1.jpg')
b,g,r = cv2.split(image6)#slow
img = cv2.merge((r,g,b))#slow
plt.imshow(img)
plt.title('color')
plt.xticks([])
plt.yticks([])
plt.show()
